# %%
import numpy as np 
import importlib
import train
import agent
import environment
import visualize
importlib.reload(train)
importlib.reload(agent)
importlib.reload(environment)
importlib.reload(visualize)
from environment import GridWorld
from agent import QAgent
from train import train
from visualize import render, watch_episode


env = GridWorld()
agent = QAgent(state_size=5, action_size=4, gamma = 0.9)
train(env, agent, episodes=2000)
watch_episode(env, agent, delay = 0.2)
#print(np.round(np.max(agent.q_table, axis=2), 2))
# Out:
# . . . . .
# . . . L .
# . . . . .
# . . . . .
# . . . . A
#
# Episode finished.
